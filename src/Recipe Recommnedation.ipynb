# %%
import pandas as pd
import ast

# Load data
recipes = pd.read_csv("/Users/seonminhwang/Downloads/archive/RAW_recipes.csv")
interactions = pd.read_csv("/Users/seonminhwang/Downloads/archive/RAW_interactions.csv")

# Ensure 'ingredients' column is properly parsed (if stored as a string list)
recipes['ingredients'] = recipes['ingredients'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# Create a dictionary mapping recipe IDs to their ingredients
recipe_ingredients = recipes.set_index('id')['ingredients'].to_dict()
recipe_names = recipes.set_index('id')['name'].to_dict()

print(f"Sample recipe ingredients: {list(recipe_ingredients.items())[:5]}")
# Out:
# Sample recipe ingredients: [(137739, ['winter squash', 'mexican seasoning', 'mixed spice', 'honey', 'butter', 'olive oil', 'salt']), (31490, ['prepared pizza crust', 'sausage patty', 'eggs', 'milk', 'salt and pepper', 'cheese']), (112140, ['ground beef', 'yellow onions', 'diced tomatoes', 'tomato paste', 'tomato soup', 'rotel tomatoes', 'kidney beans', 'water', 'chili powder', 'ground cumin', 'salt', 'lettuce', 'cheddar cheese']), (59389, ['spreadable cheese with garlic and herbs', 'new potatoes', 'shallots', 'parsley', 'tarragon', 'olive oil', 'red wine vinegar', 'salt', 'pepper', 'red bell pepper', 'yellow bell pepper']), (44061, ['tomato juice', 'apple cider vinegar', 'sugar', 'salt', 'pepper', 'clove oil', 'cinnamon oil', 'dry mustard'])]

# %%
def jaccard_similarity(set1, set2):
    set1, set2 = set(set1), set(set2)
    intersection = len(set1 & set2)
    union = len(set1 | set2)
    return intersection / union if union != 0 else 0

# %%
def get_similar_recipes(target_recipe_id, recipe_ingredients, recipe_names, exclude_ids=None, top_n=5):

    target_ingredients = recipe_ingredients.get(target_recipe_id, [])
    similarities = []
    seen_ingredient_sets = set()  # Track unique ingredient sets
    
    if exclude_ids is None:
        exclude_ids = set()
    
    for recipe_id, ingredients in recipe_ingredients.items():
        if recipe_id != target_recipe_id and recipe_id not in exclude_ids:
            sim = jaccard_similarity(target_ingredients, ingredients)
            ingredient_set = frozenset(ingredients)  # Use frozenset for immutability
            
            # Only add if this ingredient set hasn't been seen before
            if ingredient_set not in seen_ingredient_sets:
                similarities.append((recipe_id, recipe_names[recipe_id], list(ingredient_set), sim))
                seen_ingredient_sets.add(ingredient_set)
    
    # Sort by similarity in descending order
    similarities = sorted(similarities, key=lambda x: x[3], reverse=True)
    
    return similarities[:top_n]

# %%
# Example: Get top 5 similar recipes for a given recipe ID

target_recipe_id = 137739  # Replace with a valid recipe ID from your dataset
similar_recipes = get_similar_recipes(target_recipe_id, recipe_ingredients, recipe_names, exclude_ids=None, top_n=5)

print(f"Top similar recipes to '{recipe_names.get(target_recipe_id, 'Unknown Recipe')}' (ID: {target_recipe_id}):\n")

for idx, (recipe_id, name, ingredients, similarity) in enumerate(similar_recipes, start=1):
    recipe_name = recipe_names.get(recipe_id, 'Unknown Recipe')  # Handle missing
    print(f"{idx}. {recipe_name} (ID: {recipe_id})")
    print(f"   Similarity: {similarity:.2f}")
    print(f"   Ingredients: {', '.join(ingredients)}\n")
# Out:
# Top similar recipes to 'arriba   baked winter squash mexican style' (ID: 137739):
#
# 1. berber spice roasted chickpeas (ID: 514675)
#    Similarity: 0.38
#    Ingredients: dried garbanzo beans, olive oil, salt, mixed spice
#
# 2. ed s homemade microwave buttery popcorn (ID: 408958)
#    Similarity: 0.38
#    Ingredients: butter, olive oil, popcorn, salt
#
# 3. honey roasted peanuts (ID: 147856)
#    Similarity: 0.38
#    Ingredients: butter, honey, peanuts, salt
#
# 4. julia child method of preparing garlic (ID: 104441)
#    Similarity: 0.38
#    Ingredients: butter, olive oil, salt, garlic
#
# 5. potatoes rissole (ID: 72347)
#    Similarity: 0.38
#    Ingredients: butter, russet potatoes, olive oil, salt

# %%
def recommend_by_ingredients(user_id, interactions, recipe_ingredients, recipe_names, top_n=5):
 
    # Get recipes rated highly by the user
    user_rated_recipes = interactions[interactions['user_id'] == user_id]
    user_high_ratings = user_rated_recipes[user_rated_recipes['rating'] >= 4]['recipe_id']
    
    recommendations = {}

    for recipe_id in user_high_ratings:
        # Get the name of the recipe the user rated highly
        source_recipe_name = recipe_names.get(recipe_id, 'Unknown Recipe')
        
        # Find similar recipes
        similar_recipes = get_similar_recipes(recipe_id, recipe_ingredients, recipe_names, exclude_ids=set(user_high_ratings), top_n=top_n)
        
        # Add to recommendations dictionary
        recommendations[source_recipe_name] = similar_recipes

    return recommendations

# %%
# Example: Get ingredient-based recommendations for a specific user
user_id = 38094  # Replace with a valid user ID
ingredient_based_recommendations = recommend_by_ingredients(user_id, interactions, recipe_ingredients, recipe_names, top_n=5)

# %%
print(f"Ingredient-based recommendations for user {user_id}:\n")

for source_recipe_name, similar_recipes in ingredient_based_recommendations.items():
    print(f"Recipes similar to '{source_recipe_name}':\n")
    for idx, (recipe_id, name, ingredients, similarity) in enumerate(similar_recipes, start=1):
        print(f"  {idx}. {name} (ID: {recipe_id})")
        print(f"     Similarity: {similarity:.2f}")
        print(f"     Ingredients: {', '.join(ingredients)}\n")
    print("-" * 50)
# Out:
# Ingredient-based recommendations for user 38094:
#
# Recipes similar to 'white bean   green chile pepper soup':
#
#   1. zesty pumpkin soup with chili cream (ID: 78404)
#      Similarity: 0.27
#      Ingredients: diced green chilis, ground cumin, water, sour cream, solid-pack pumpkin, fresh cilantro leaves, chicken broth, ground red pepper, chili powder, garlic powder
#
#   2. 5 minute wet beef   green chile burritos (ID: 263505)
#      Similarity: 0.25
#      Ingredients: beef broth, ground cumin, diced green chilies, monterey jack pepper cheese, sour cream, refried beans, wondra flour, roast beef in gravy, flour tortillas, chili powder, garlic powder
#
#   3. southwestern spiced chicken   black bean stew (ID: 245090)
#      Similarity: 0.25
#      Ingredients: corn tortilla strips, extra virgin olive oil, red bell pepper, ground cumin, bacon, sour cream, chipotle pepper, yellow onion, kosher salt & freshly ground black pepper, beer, skinless chicken thighs, reduced-sodium chicken broth, fresh cilantro leaves, lime, black beans, chili powder
#
#   4. southwest chowder (ID: 199420)
#      Similarity: 0.24
#      Ingredients: cream-style corn, ground cumin, bacon, mexicorn, diced green chilies, sour cream, flour, chicken broth, onion, chili powder, frozen southern style hash brown potatoes, garlic powder
#
#   5. broccoli  slaw (ID: 285741)
#      Similarity: 0.23
#      Ingredients: extra virgin olive oil, ground cumin, broccoli slaw mix, lemon juice, onion powder, salt and pepper, garlic powder
#
# --------------------------------------------------
# Recipes similar to 'black beans with mango sauce':
#
#   1. black bean salsa (ID: 60617)
#      Similarity: 0.41
#      Ingredients: fresh cilantro, olive oil, red peppers, frozen corn, lime juice, salt, tomatoes, garlic, cumin, onion, black beans, chili powder
#
#   2. cilantro jalapeno hummus (ID: 97552)
#      Similarity: 0.36
#      Ingredients: fresh cilantro, olive oil, jalapeno peppers, lime juice, salt, garlic, garbanzo beans
#
#   3. colorful vegetable salad (ID: 80028)
#      Similarity: 0.35
#      Ingredients: fresh cilantro, olive oil, lime juice, salt, tomatoes, sweet red pepper, garlic, pepper, black beans, green pepper, canned corn
#
#   4. green chili salsa dip  beware very hot (ID: 8008)
#      Similarity: 0.35
#      Ingredients: fresh cilantro, jalapeno peppers, olive oil, lime juice, fresh tarragon, sugar, black pepper, salt, garlic, yellow onion, tomatillos
#
#   5. bahamian grilled fish (ID: 372932)
#      Similarity: 0.33
#      Ingredients: olive oil, lime juice, black pepper, garlic cloves, salt, fish fillets, fresh ginger, scotch bonnet pepper
#
# --------------------------------------------------
# Recipes similar to 'warm spinach salad':
#
#   1. buca di beppo red wine vinaigrette (ID: 283613)
#      Similarity: 0.33
#      Ingredients: olive oil, black pepper, salt, dried oregano, garlic, dry mustard, red wine vinegar, red onion
#
#   2. fall salad (ID: 137433)
#      Similarity: 0.33
#      Ingredients: olive oil, fresh cranberries, blue cheese, sliced almonds, salt, water, garlic, ground black pepper, mixed salad greens, red wine vinegar, red onion, dijon mustard
#
#   3. panzanella  bread salad (ID: 58958)
#      Similarity: 0.33
#      Ingredients: olive oil, italian bread, fresh basil, mixed greens, salt, tomatoes, garlic, pepper, red wine vinegar, fresh parsley, cucumber, red onion
#
#   4. warm herbed potato salad (ID: 50136)
#      Similarity: 0.33
#      Ingredients: olive oil, black pepper, salt, yukon gold potatoes, red wine vinegar, fresh parsley, red onion, dried italian seasoning
#
#   5. italian marinated vegetables (ID: 299645)
#      Similarity: 0.32
#      Ingredients: olive oil, honey, green peppers, sugar, mushroom, red pepper flakes, salt, garlic, pepper, red wine vinegar, cauliflower, fresh parsley, red onions
#
# --------------------------------------------------
# Recipes similar to 'roasted asparagus   shiitake mushrooms':
#
#   1. roasted squash with balsamic vinegar (ID: 143810)
#      Similarity: 0.43
#      Ingredients: butternut squash, salt & freshly ground black pepper, extra virgin olive oil, balsamic vinegar
#
#   2. arugula  apple    goat cheese salad (ID: 255753)
#      Similarity: 0.33
#      Ingredients: fresh goat cheese, extra virgin olive oil, arugula, salt & freshly ground black pepper, balsamic vinegar, apple
#
#   3. balsamic browned butter over tilapia fillets (ID: 321088)
#      Similarity: 0.33
#      Ingredients: extra virgin olive oil, all-purpose flour, salt & freshly ground black pepper, tilapia fillets, balsamic vinegar, butter
#
#   4. prosciutto wrapped endive w  balsamic fig reduction   rachael ra (ID: 114770)
#      Similarity: 0.33
#      Ingredients: prosciutto, extra virgin olive oil, belgian endive, salt & freshly ground black pepper, balsamic vinegar, dried figs
#
#   5. warm garlic balsamic dressing (ID: 119433)
#      Similarity: 0.33
#      Ingredients: extra virgin olive oil, garlic cloves, dark brown sugar, red wine vinegar, salt & freshly ground black pepper, balsamic vinegar
#
# --------------------------------------------------
# Recipes similar to 'low carb key lime pie':
#
#   1. sugar free sweet and sour mix (ID: 237957)
#      Similarity: 0.38
#      Ingredients: lemon juice, water, lime juice, artificial sweetener
#
#   2. key lime cream cheese frosting (ID: 328247)
#      Similarity: 0.33
#      Ingredients: unsalted butter, lime juice, powdered sugar, lime zest, cream cheese
#
#   3. lime syrup (ID: 173690)
#      Similarity: 0.33
#      Ingredients: lime juice, lime zest, water, cardamom pods, caster sugar
#
#   4. margarita   jigglers (ID: 149087)
#      Similarity: 0.33
#      Ingredients: unflavored gelatin, tequila, lime juice, sugar-free lime gelatin, boiling water
#
#   5. strawberry and lime sorbet  ww (ID: 498993)
#      Similarity: 0.33
#      Ingredients: strawberries, lime juice, sugar, lime zest, water
#
# --------------------------------------------------
# Recipes similar to 'slow cooker hoppin  john':
#
#   1. best hoppin   john  combo (ID: 90891)
#      Similarity: 0.43
#      Ingredients: celery, ham, rice, bacon, chicken broth, barbecue sauce, onion, salt and pepper, tabasco sauce, black-eyed peas
#
#   2. soupa avgolemono (ID: 169328)
#      Similarity: 0.42
#      Ingredients: celery, carrot, fresh lemon juice, rice, chicken broth, eggs, onion
#
#   3. braised lentils (ID: 362021)
#      Similarity: 0.33
#      Ingredients: celery, carrot, olive oil, green lentils, chicken broth, onion
#
#   4. chicken and rice soup  crock pot (ID: 317245)
#      Similarity: 0.33
#      Ingredients: boneless chicken breast, carrot, celery, rice, fresh mushrooms, ground sage, pepper, vegetables, chicken broth, onion
#
#   5. lentil vegetable soup with ham (ID: 391405)
#      Similarity: 0.33
#      Ingredients: dried lentils, carrot, celery, ham, ham hock, chicken broth, salt and pepper, onion, stewed tomatoes, crushed red pepper flakes
#
# --------------------------------------------------
# Recipes similar to 'west indian pumpkin soup':
#
#   1. autumn pumpkin and squash soup (ID: 104028)
#      Similarity: 0.27
#      Ingredients: brown sugar, pumpkin, heavy cream, salt, acorn squash, cayenne pepper, butternut squash, chicken stock, butter, nutmeg, fresh ginger, onions
#
#   2. simple potato curry (ID: 11848)
#      Similarity: 0.26
#      Ingredients: curry powder, fresh lemon juice, potatoes, black pepper, coriander, frozen peas, salt, garlic, chicken stock, white wine vinegar, butter, fresh ginger, onions
#
#   3. sorrel and potato soup potage  l oseille (ID: 135883)
#      Similarity: 0.26
#      Ingredients: white wine, shallot, bay leaves, heavy cream, fresh sorrel, salt, garlic, white pepper, chicken stock, yukon gold potatoes, ground nutmeg, butter, lemon thyme
#
#   4. sugar and spice turkey breast with peach chutney (ID: 282421)
#      Similarity: 0.24
#      Ingredients: curry powder, peaches, water, salt and pepper, vinegar, oil, cinnamon, orange zest, brown sugar, turkey breast, cinnamon stick, black pepper, cumin, fresh ginger, chili powder, ground ginger, white onion, fresh thyme, cayenne pepper, kosher salt
#
#   5. chive and garlic mashed potatoes (ID: 104042)
#      Similarity: 0.24
#      Ingredients: bay leaves, salt, garlic, chives, yukon gold potatoes, butter, fresh thyme, fresh ground pepper, heavy cream, kosher salt
#
# --------------------------------------------------
# Recipes similar to 'oh my d lux chocolate chip cookies':
#
#   1. chocolate coconut dream bars (ID: 28807)
#      Similarity: 0.73
#      Ingredients: brown sugar, salt, sweetened flaked coconut, semi-sweet chocolate chips, vanilla, baking powder, flour, eggs, butter
#
#   2. blonde brownies (ID: 183229)
#      Similarity: 0.64
#      Ingredients: brown sugar, salt, walnuts, semi-sweet chocolate chips, baking powder, flour, eggs, butter
#
#   3. chinese chews (ID: 48132)
#      Similarity: 0.64
#      Ingredients: brown sugar, walnuts, vanilla, baking powder, flour, eggs, coconut, butter
#
#   4. zebras (ID: 306020)
#      Similarity: 0.64
#      Ingredients: light brown sugar, walnuts, semi-sweet chocolate chips, vanilla, baking powder, flour, eggs, butter
#
#   5. lazy gourmet s chocolate brownies (ID: 367614)
#      Similarity: 0.58
#      Ingredients: brown sugar, white sugar, cocoa, walnuts, vanilla, baking powder, flour, eggs, butter
#
# --------------------------------------------------
# Recipes similar to 'honey roasted pork loin':
#
#   1. sea bass baked with onion and honey (ID: 92239)
#      Similarity: 0.40
#      Ingredients: olive oil, honey, sea bass, garlic, white onion, salt and pepper, thyme
#
#   2. citrus balsamic glazed salmon (ID: 111049)
#      Similarity: 0.36
#      Ingredients: cornstarch, olive oil, brown sugar, orange juice, chicken broth, salt and pepper, salmon fillets, balsamic vinegar
#
#   3. chicken thighs with mustard citrus sauce (ID: 409847)
#      Similarity: 0.33
#      Ingredients: olive oil, honey, orange zest, orange juice, garlic, lemon juice, chicken broth, salt and pepper, chicken thighs, shallots, crushed red pepper flakes, worcestershire sauce, dijon mustard
#
#   4. grilled radicchio (ID: 245633)
#      Similarity: 0.33
#      Ingredients: olive oil, honey, salt and pepper, balsamic vinegar, radicchio
#
#   5. honey   mustard glazed parsnips (ID: 363302)
#      Similarity: 0.33
#      Ingredients: olive oil, honey, coarse grain mustard, salt and pepper, parsnip
#
# --------------------------------------------------
# Recipes similar to 'bananas au gratin':
#
#   1. they won t know it s not cream cheese cheesecake (ID: 192584)
#      Similarity: 0.40
#      Ingredients: sugar, graham cracker crust, low fat cottage cheese, vanilla extract, lemon juice, eggs
#
#   2. banana topping for ice cream  with variations (ID: 87141)
#      Similarity: 0.36
#      Ingredients: unsalted butter, sugar, vanilla extract, banana liqueur, bananas, ground nutmeg, ground cinnamon
#
#   3. apple cinnamon pancake syrup (ID: 273318)
#      Similarity: 0.33
#      Ingredients: sugar, ground cinnamon, apple juice, vanilla extract
#
#   4. banana milk from yemen (ID: 513585)
#      Similarity: 0.33
#      Ingredients: sugar, vanilla extract, bananas, milk
#
#   5. banana paletas (ID: 456850)
#      Similarity: 0.33
#      Ingredients: sugar, whole milk, vanilla extract, bananas
#
# --------------------------------------------------
# Recipes similar to 'toasted orzo pilaf':
#
#   1. cauliflower with scallions (ID: 296852)
#      Similarity: 0.33
#      Ingredients: butter, salt and pepper, cauliflower florets, scallions
#
#   2. herbed orzo with pine nuts (ID: 168327)
#      Similarity: 0.33
#      Ingredients: pine nuts, fresh lemon juice, fresh basil, garlic cloves, salt and pepper, fresh parsley, butter, orzo pasta
#
#   3. toasted orzo with pine nuts (ID: 409370)
#      Similarity: 0.33
#      Ingredients: pine nuts, garlic cloves, chicken broth, salt and pepper, onion, fresh parsley, butter, orzo pasta
#
#   4. orzo   pignoli   pasta   pine nuts (ID: 59173)
#      Similarity: 0.30
#      Ingredients: pine nuts, extra virgin olive oil, dried basil, salt and pepper, orzo pasta
#
#   5. peas  mushrooms  and scallions (ID: 83159)
#      Similarity: 0.30
#      Ingredients: sliced mushrooms, frozen peas, butter, salt and pepper, scallions
#
# --------------------------------------------------
# Recipes similar to 'rocky mount chicken':
#
#   1. chicken delicious (ID: 137633)
#      Similarity: 1.00
#      Ingredients: boneless skinless chicken breasts, bacon, sour cream, dried beef, cream of mushroom soup
#
#   2. nana s chicken in the oven (ID: 409741)
#      Similarity: 0.83
#      Ingredients: boneless skinless chicken breasts, bacon, sour cream, dried beef, salt and pepper, cream of mushroom soup
#
#   3. company chicken with dried beef (ID: 38366)
#      Similarity: 0.71
#      Ingredients: boneless skinless chicken breasts, bacon, sour cream, dried beef, paprika, cream of mushroom soup, cream cheese
#
#   4. slow cooker chicken supreme (ID: 127874)
#      Similarity: 0.71
#      Ingredients: pasta, all-purpose flour, boneless skinless chicken breasts, bacon, sour cream, dried beef, cream of mushroom soup
#
#   5. dried beef chicken casserole (ID: 275263)
#      Similarity: 0.67
#      Ingredients: boneless chicken breasts, bacon, sour cream, dried beef, cream of mushroom soup
#
# --------------------------------------------------
# Recipes similar to 'beans  black eyed peas  and cashew salad':
#
#   1. hoppin  john salad (ID: 178168)
#      Similarity: 0.25
#      Ingredients: celery ribs, garlic clove, jalapeno peppers, olive oil, yellow bell pepper, red bell pepper, ground cumin, salt, ground black pepper, onion, red wine vinegar, fresh parsley, balsamic vinegar, cooked bacon, black-eyed peas
#
#   2. mediterranean pantry supper (ID: 57843)
#      Similarity: 0.25
#      Ingredients: celery, olive oil, rice, red bell pepper, tuna in water, capers, onion, black olives, balsamic vinegar, garlic powder
#
#   3. orange apricot rice salad (ID: 94852)
#      Similarity: 0.25
#      Ingredients: cooked rice, olive oil, orange zest, baby spinach leaves, green onions, pine nuts, orange juice, balsamic vinegar, dried apricot, garlic powder
#
#   4. orzo  pea  and pepper salad (ID: 197777)
#      Similarity: 0.25
#      Ingredients: garlic clove, olive oil, green onions, red bell pepper, water, frozen peas, pepper, balsamic vinegar, orzo pasta, dijon mustard
#
#   5. blueberry balsamic barbecue sauce (ID: 205470)
#      Similarity: 0.23
#      Ingredients: sugar, salt, ketchup, balsamic vinegar, blueberries, garlic powder
#
# --------------------------------------------------
# Recipes similar to 'veal cutlets with olive  tomato and anchovy sauce':
#
#   1. roast tomato salad (ID: 42452)
#      Similarity: 0.56
#      Ingredients: olive oil, anchovy fillets, tomatoes, garlic, basil leaves
#
#   2. pasta with tomatoes  olives and capers (ID: 64473)
#      Similarity: 0.42
#      Ingredients: extra virgin olive oil, angel hair pasta, tomatoes, garlic, black olives, flat leaf parsley, capers, salt & freshly ground black pepper
#
#   3. olive spread (ID: 16149)
#      Similarity: 0.40
#      Ingredients: olive oil, garlic, green olives, black olives, capers
#
#   4. pissaladiere (ID: 63099)
#      Similarity: 0.38
#      Ingredients: olive oil, fresh parsley, anchovy fillets, tomatoes, garlic, parmesan cheese, onion, pastry dough, black olives
#
#   5. couldn t be easier margherita pizza (ID: 318389)
#      Similarity: 0.36
#      Ingredients: olive oil, fresh mozzarella cheese, tomatoes, garlic, burrito-size flour tortilla, basil leaves
#
# --------------------------------------------------
# Recipes similar to 'key lime cheesecake squares':
#
#   1. chocolate strawberry turnovers (ID: 420578)
#      Similarity: 0.31
#      Ingredients: egg, bittersweet chocolate, lime zest, puff pastry sheet, strawberry, butter, granulated sugar
#
#   2. key lime mascarpone cheesecake (ID: 115975)
#      Similarity: 0.31
#      Ingredients: egg, sugar, key lime juice, mascarpone cheese, graham cracker crumbs, butter, cream cheese
#
#   3. kissey   face cream cheese cookies (ID: 283641)
#      Similarity: 0.31
#      Ingredients: egg, all-purpose flour, vanilla extract, butter, granulated sugar, hershey chocolate kisses, cream cheese
#
#   4. mincemeat cream cheese pastries (ID: 226746)
#      Similarity: 0.31
#      Ingredients: egg, mincemeat, all-purpose flour, walnuts, butter, granulated sugar, cream cheese
#
#   5. blueberry cream cheesecake (ID: 18795)
#      Similarity: 0.30
#      Ingredients: almond extract, vanilla wafer crumbs, egg, graham wafer crumbs, fresh lemon juice, blanched almond, vanilla extract, water, sour cream, tapioca starch, blueberries, lemon juice, eggs, butter, granulated sugar, cream cheese
#
# --------------------------------------------------
# Recipes similar to '2 step pumpkin cheesecake':
#
#   1. easy pumpkin pie croissants (ID: 490204)
#      Similarity: 0.57
#      Ingredients: sugar, pumpkin pie spice, pillsbury refrigerated crescent dinner rolls, canned pumpkin, cream cheese
#
#   2. pumpkin cream cheese (ID: 211885)
#      Similarity: 0.57
#      Ingredients: sugar, pumpkin pie spice, vanilla, canned pumpkin, cream cheese
#
#   3. crock pot pumpkin spiced latte (ID: 332100)
#      Similarity: 0.44
#      Ingredients: sugar, pumpkin pie spice, vanilla, milk, brewed coffee, whipped topping, canned pumpkin
#
#   4. gingersnap pumpkin pie recipe  tasteofhome com (ID: 339768)
#      Similarity: 0.42
#      Ingredients: sugar, pumpkin pie spice, vanilla extract, canned pumpkin, milk, ground cinnamon, butter, instant butterscotch pudding mix, gingersnaps, whipped topping, cream cheese
#
#   5. individual pumpkin cheesecakes (ID: 334753)
#      Similarity: 0.40
#      Ingredients: cornstarch, gingersnap cookies, sugar, pumpkin pie spice, light corn syrup, eggs, canned pumpkin, cream cheese
#
# --------------------------------------------------
# Recipes similar to 'oven fried eggplant  aubergine':
#
#   1. stacked eggplant  aubergine  parmesan (ID: 274840)
#      Similarity: 0.30
#      Ingredients: margarine, salt, tomatoes, eggplant, parmesan cheese, onion
#
#   2. chicken and eggplant casserole (ID: 256692)
#      Similarity: 0.29
#      Ingredients: mushroom, green bell pepper, reduced-fat mozzarella cheese, eggplant, parmesan cheese, ground black pepper, onion, diced tomatoes, boneless skinless chicken breast, dried italian seasoning, garlic powder
#
#   3. jalapeo and cheese topped  eggplant (ID: 324098)
#      Similarity: 0.29
#      Ingredients: low-fat sour cream, garlic powder, pickled jalapeno peppers, salt, fresh ground black pepper, eggplant, parmesan cheese, onion powder, fine dry breadcrumb, vegetable oil cooking spray, low-fat mayonnaise
#
#   4. crispy baked eggplant (ID: 346106)
#      Similarity: 0.27
#      Ingredients: mayonnaise, dried onion flakes, dry breadcrumbs, salt, eggplant, parmesan cheese, dried italian seasoning
#
#   5. crispy eggplant (ID: 179903)
#      Similarity: 0.27
#      Ingredients: mayonnaise, italian seasoning, salt, parmesan cheese, eggplant, onion, seasoned stuffing mix
#
# --------------------------------------------------
# Recipes similar to 'low fat chicken cassoulet':
#
#   1. split pea soup   vegan   vegetarian (ID: 161915)
#      Similarity: 0.35
#      Ingredients: celery ribs, olive oil, carrots, low sodium chicken broth, yellow onions, garlic cloves, black pepper, split peas, bay leaf, kosher salt
#
#   2. carrot thyme soup (ID: 182530)
#      Similarity: 0.32
#      Ingredients: olive oil, parsley, carrots, sugar, low sodium chicken broth, yellow onions, salt, garlic, white pepper, butter, champagne, dried thyme
#
#   3. bean and macaroni soup (ID: 31529)
#      Similarity: 0.29
#      Ingredients: great northern beans, celery, elbow macaroni, olive oil, carrots, fresh mushrooms, fresh tomatoes, fresh ground black pepper, dried oregano, garlic, bay leaf, dried sage, onion, dried thyme
#
#   4. boiled pork dinner (ID: 151620)
#      Similarity: 0.28
#      Ingredients: olive oil, head of cabbage, pork sirloin roast, potatoes, carrots, low sodium chicken broth, dry white wine, instant garlic, onions, dried thyme
#
#   5. braised lamb shanks with rosemary (ID: 114467)
#      Similarity: 0.26
#      Ingredients: celery ribs, olive oil, carrots, yellow onions, garlic cloves, lamb shanks, beef stock, bay leaf, dried rosemary, salt and pepper, full-bodied red wine
#
# --------------------------------------------------
# Recipes similar to 'snow peas with red bell peppers':
#
#   1. buttered snow and green peas (ID: 415550)
#      Similarity: 0.43
#      Ingredients: fresh chives, snow peas, salt and pepper, butter, tiny peas
#
#   2. orange asparagus (ID: 232028)
#      Similarity: 0.43
#      Ingredients: orange juice, salt and pepper, butter, asparagus, orange, zest of
#
#   3. erin s orange roasted chicken (ID: 14533)
#      Similarity: 0.38
#      Ingredients: garlic cloves, orange juice, orange, salt and pepper, butter, roasting chickens
#
#   4. fragrant citrus tilapia (ID: 255885)
#      Similarity: 0.38
#      Ingredients: orange zest, orange juice, tarragon, salt and pepper, tilapia fillet, butter
#
#   5. juicy cornish game hens (ID: 52624)
#      Similarity: 0.38
#      Ingredients: honey, orange juice, cornish hens, salt and pepper, butter, chili powder
#
# --------------------------------------------------
# Recipes similar to 'southwest spaghetti squash':
#
#   1. black jack monterey beans  slow cooker (ID: 119444)
#      Similarity: 0.31
#      Ingredients: hot pepper sauce, whole kernel corn, black pepper, monterey jack cheese, green chilies, garlic salt, butter, black beans, red onion
#
#   2. tex mex stuffed acorn squash (ID: 335157)
#      Similarity: 0.31
#      Ingredients: olive oil, pine nuts, black pepper, ground cumin, tomatoes, monterey jack cheese, acorn squash, scallions, black beans
#
#   3. black bean blender soup (ID: 80568)
#      Similarity: 0.30
#      Ingredients: chunky salsa, ground cumin, cilantro, vegetable broth, black beans
#
#   4. simply elegant black bean soup (ID: 288938)
#      Similarity: 0.30
#      Ingredients: white shoepeg corn, sour cream, cilantro, mexican-style tomatoes, black beans
#
#   5. fiesta rib eye steaks (ID: 311355)
#      Similarity: 0.29
#      Ingredients: rib eye steaks, olive oil, black pepper, lime, juice of, ground cumin, salsa, monterey jack cheese, red pepper, sour cream, cheddar cheese, garlic salt, cilantro, green pepper, chili powder
#
# --------------------------------------------------
# Recipes similar to 'fried broccoli':
#
#   1. steamed broccoli with garlic and bread crumbs (ID: 364030)
#      Similarity: 0.44
#      Ingredients: olive oil, breadcrumbs, broccoli, salt, oregano, garlic, ground pepper
#
#   2. crunchy rosemary potatoes (ID: 445100)
#      Similarity: 0.43
#      Ingredients: olive oil, rosemary, salt, potatoes
#
#   3. pan roasted cauliflower with pine nuts  garlic and rosemary (ID: 264586)
#      Similarity: 0.40
#      Ingredients: olive oil, pine nuts, breadcrumbs, salt, garlic, pepper, rosemary, cauliflower
#
#   4. broccoli with lemon (ID: 5482)
#      Similarity: 0.38
#      Ingredients: olive oil, broccoli, lemon, juice and zest of, salt, pepper
#
#   5. grilled chicken thighs (ID: 166631)
#      Similarity: 0.38
#      Ingredients: olive oil, salt, pepper, rosemary, boneless skinless chicken thighs
#
# --------------------------------------------------
# Recipes similar to 'portuguese pork ragout with sweet peppers':
#
#   1. moroccan spiced grilled chicken breasts (ID: 456810)
#      Similarity: 0.39
#      Ingredients: fresh cilantro, olive oil, garlic cloves, ground cumin, salt, fresh ground black pepper, boneless skinless chicken breasts, paprika, plain yogurt
#
#   2. sauteed pork medallions with lemon garlic sauce (ID: 471523)
#      Similarity: 0.39
#      Ingredients: pork tenderloin, olive oil, black pepper, garlic cloves, salt, lemon juice, chicken broth, dry white wine, fresh parsley
#
#   3. roasted red pepper   garlic dip (ID: 287420)
#      Similarity: 0.37
#      Ingredients: fresh cilantro, olive oil, garlic cloves, ground cumin, salt, sour cream, pepper, lemon juice, red bell peppers, cream cheese
#
#   4. tivoli s cilantro grilled chicken breast (ID: 216627)
#      Similarity: 0.35
#      Ingredients: fresh cilantro, boneless skinless chicken breast halves, olive oil, shallot, black pepper, garlic cloves, ground cumin, salt, salsa, lemon juice, cayenne pepper
#
#   5. fish marinade for people who hate fish (ID: 265932)
#      Similarity: 0.33
#      Ingredients: olive oil, shallot, garlic cloves, salt, pepper, lemon juice, paprika, basil
#
# --------------------------------------------------
# Recipes similar to 'easy creamy yogurt pie':
#
#   1. lemon yogurt jelly (ID: 391442)
#      Similarity: 0.50
#      Ingredients: unflavored gelatin, sugar, vanilla extract, water, lemon juice, plain yogurt, lemons
#
#   2. devonshire cream trifle or parfait (ID: 384668)
#      Similarity: 0.42
#      Ingredients: unflavored gelatin, sugar, vanilla extract, water, whipping cream, fresh fruit, sour cream, sponge cakes, peach brandy
#
#   3. horchata smoothie (ID: 67261)
#      Similarity: 0.40
#      Ingredients: sugar, vanilla extract, water, milk, ground cinnamon, plain yogurt
#
#   4. orange bonus smoothie (ID: 427699)
#      Similarity: 0.40
#      Ingredients: ice cube, sugar, vanilla extract, water, navel oranges, plain yogurt
#
#   5. topping  low fat whipped (ID: 7948)
#      Similarity: 0.40
#      Ingredients: unflavored gelatin, sugar, vanilla extract, evaporated skim milk, water, lemon juice
#
# --------------------------------------------------
# Recipes similar to 'quick broccoli slaw':
#
#   1. spicy chili lime mayo (ID: 434962)
#      Similarity: 0.50
#      Ingredients: lime juice, mayonnaise, salt, ground cayenne pepper, chili powder
#
#   2. skewered scallops with a spicy rub (ID: 92662)
#      Similarity: 0.45
#      Ingredients: olive oil, lime juice, scallops, ground cumin, chili powder, oregano, salt, paprika, cayenne pepper
#
#   3. grilled florida tuna (ID: 99825)
#      Similarity: 0.44
#      Ingredients: lime juice, mayonnaise, tuna steaks, ground cumin, garlic, cayenne pepper
#
#   4. chili cumin salt for french fries (ID: 157873)
#      Similarity: 0.43
#      Ingredients: ground cumin, salt, chili powder
#
#   5. seasoned tortilla strips (ID: 100646)
#      Similarity: 0.40
#      Ingredients: ground cumin, chili powder, salt, tabasco sauce, 6-inch corn tortillas, vegetable oil, cayenne pepper
#
# --------------------------------------------------
# Recipes similar to 'squash casserole  charlotte s barclay cafeteria':
#
#   1. kratzede   pancake scrapings (ID: 478826)
#      Similarity: 0.55
#      Ingredients: sugar, salt, milk, eggs, butter, mineral water, plain flour
#
#   2. aunt fanny s baked yellow squash (ID: 195147)
#      Similarity: 0.50
#      Ingredients: sugar, salt, pepper, eggs, onion, butter, cracker meal, yellow squash
#
#   3. corn pudding  or scalloped corn (ID: 9399)
#      Similarity: 0.50
#      Ingredients: sugar, frozen whole kernel corn, salt, milk, pepper, flour, eggs, butter
#
#   4. koshie  potato casserole (ID: 220942)
#      Similarity: 0.50
#      Ingredients: potatoes, salt, bacon, milk, pepper, eggs, onion, butter
#
#   5. ms  annette s corn pudding (ID: 292225)
#      Similarity: 0.50
#      Ingredients: creamed corn, sugar, salt, milk, pepper, flour, eggs, butter
#
# --------------------------------------------------
# Recipes similar to 'sauteed salmon with lime honey sauce':
#
#   1. top secret honey lime chicken wing sauce (ID: 424212)
#      Similarity: 0.45
#      Ingredients: fresh cilantro, brown sugar, limes, honey, red pepper flakes, garlic cloves, lime zest, salt and pepper, butter, hot sauce
#
#   2. broiled honey lime salmon (ID: 520577)
#      Similarity: 0.40
#      Ingredients: fresh cilantro, olive oil, honey, garlic pepper seasoning, lime zest, fresh lime juice, salmon fillets, low sodium soy sauce
#
#   3. grilled salmon with key lime butter (ID: 268379)
#      Similarity: 0.38
#      Ingredients: lime zest, fresh lime juice, salt and pepper, salmon fillets, butter
#
#   4. lime curd (ID: 216466)
#      Similarity: 0.38
#      Ingredients: limes, sugar, lime zest, eggs, butter
#
#   5. southwest grilled salmon with cilantro lime butter (ID: 11478)
#      Similarity: 0.36
#      Ingredients: fresh cilantro, olive oil, limes, salt, pepper, salmon fillets, cumin, butter, chili powder
#
# --------------------------------------------------
# Recipes similar to 'sweet potato stew with orange juice and black beans':
#
#   1. bourbon sweet potatoes (ID: 182888)
#      Similarity: 0.38
#      Ingredients: orange zest, sweet potatoes, brown sugar, salt, orange juice, bourbon, flour, butter
#
#   2. cheddar pennies (ID: 50916)
#      Similarity: 0.36
#      Ingredients: salt, cheddar cheese, flour, butter, chili powder
#
#   3. madras sweet potatoes (ID: 197361)
#      Similarity: 0.36
#      Ingredients: sweet potatoes, honey, madras curry powder, salt, butter
#
#   4. oven baked orange chicken (ID: 124496)
#      Similarity: 0.36
#      Ingredients: honey, breadcrumbs, boneless skinless chicken breasts, salt, orange juice, flour, thyme, paprika, butter
#
#   5. sweet potatoes with honey (ID: 169551)
#      Similarity: 0.36
#      Ingredients: sweet potatoes, honey, salt, orange juice, walnuts, brandy, butter, granulated sugar, nutmeg
#
# --------------------------------------------------
# Recipes similar to 'yummy n  easiest  warm blueberry sauce':
#
#   1. autumn holiday tea (ID: 76906)
#      Similarity: 0.75
#      Ingredients: cinnamon, nutmeg, sugar
#
#   2. cinnamon nutmeg whipped cream (ID: 505907)
#      Similarity: 0.60
#      Ingredients: heavy cream, cinnamon, nutmeg, sugar
#
#   3. simple baked apples (ID: 354844)
#      Similarity: 0.60
#      Ingredients: apples, cinnamon, nutmeg, sugar
#
#   4. blueberry spice sauce (ID: 7411)
#      Similarity: 0.57
#      Ingredients: cornstarch, sugar, hot water, lemon juice, blueberries, cinnamon, nutmeg
#
#   5. amazing apple strudel (ID: 24452)
#      Similarity: 0.50
#      Ingredients: sugar, golden delicious apples, cinnamon, nutmeg, puff pastry
#
# --------------------------------------------------
# Recipes similar to 'couscous with chickpeas':
#
#   1. macadamia nut hummus (ID: 455895)
#      Similarity: 0.42
#      Ingredients: olive oil, water, macadamia nuts, garlic, lemon juice, salt and pepper, garbanzo beans, basil leaves
#
#   2. curry roasted broccoflower (ID: 340690)
#      Similarity: 0.36
#      Ingredients: broccoflower, olive oil, curry powder, lemon juice, salt and pepper, garlic powder
#
#   3. everyday vinaigrette with lots of variations (ID: 216121)
#      Similarity: 0.36
#      Ingredients: garlic clove, olive oil, water, lemon juice, salt and pepper, dijon mustard
#
#   4. baked couscous with tomato and pesto (ID: 398307)
#      Similarity: 0.36
#      Ingredients: couscous, olive oil, baby spinach leaves, pine nuts, roma tomatoes, parmesan cheese, chicken stock, lemon juice, salt and pepper, thyme leaves
#
#   5. magic bullet gazpacho (ID: 395741)
#      Similarity: 0.36
#      Ingredients: garlic clove, olive oil, yogurt, celery salt, water, tomatoes, lemon juice, cilantro, salt and pepper, cucumber
#
# --------------------------------------------------
# Recipes similar to 'mediterranean broccoli salad':
#
#   1. amazing watermelon greek salad with feta (ID: 290853)
#      Similarity: 0.42
#      Ingredients: extra virgin olive oil, seedless watermelon, fresh lime juice, feta cheese, black olives, balsamic vinegar, fresh parsley, red onion
#
#   2. savoury tarte tatin (ID: 48117)
#      Similarity: 0.38
#      Ingredients: garlic clove, extra virgin olive oil, premade puff pastry, feta cheese, mushrooms, black olives, balsamic vinegar, red onion, cherry tomatoes
#
#   3. traditional greek salad (ID: 236001)
#      Similarity: 0.38
#      Ingredients: extra virgin olive oil, salt, oregano, tomatoes, lemon juice, feta cheese, black olives, cucumber, red onions
#
#   4. watermelon  cucumber and feta salad (ID: 382207)
#      Similarity: 0.36
#      Ingredients: olive oil, salt, mint, feta cheese, black olives, balsamic vinegar, english cucumber, watermelon, red onion, basil
#
#   5. chopped italian salad with italian vinaigrette (ID: 275739)
#      Similarity: 0.35
#      Ingredients: olive oil, black pepper, salt, oregano, romaine lettuce, salami, dijon mustard, roasted red peppers, thyme, balsamic vinegar, black olives, provolone cheese, red onion, basil
#
# --------------------------------------------------
# Recipes similar to 'homemade microwave popcorn':
#
#   1. ed s homemade microwave buttery popcorn (ID: 408958)
#      Similarity: 0.75
#      Ingredients: butter, olive oil, popcorn, salt
#
#   2. popcorn  stove top (ID: 119045)
#      Similarity: 0.75
#      Ingredients: butter, oil, popcorn, salt
#
#   3. easy microwave popcorn (ID: 287921)
#      Similarity: 0.67
#      Ingredients: salt, popcorn
#
#   4. pop culture   popcorn with 6 mixes (ID: 364859)
#      Similarity: 0.67
#      Ingredients: butter, popcorn
#
#   5. lemon and dill popcorn (ID: 398125)
#      Similarity: 0.60
#      Ingredients: lemon peel, salt, popcorn, dill weed, butter
#
# --------------------------------------------------
# Recipes similar to 'lentil and orzo salad':
#
#   1. pasta with chickpea sauce (ID: 170195)
#      Similarity: 0.30
#      Ingredients: pasta, extra virgin olive oil, garlic cloves, tomatoes, dried chili, bay leaf, onion, chickpeas, italian parsley, salt & freshly ground black pepper, basil leaves
#
#   2. dandelion greens  or arugula  and avocado salad (ID: 269005)
#      Similarity: 0.26
#      Ingredients: fresh lemon juice, extra virgin olive oil, dried dill, avocados, tomatoes, salt & freshly ground black pepper, cucumber, red onions, dandelion greens
#
#   3. clear spinach and tomato soup ww friendly core (ID: 180172)
#      Similarity: 0.25
#      Ingredients: extra virgin olive oil, spinach, fresh basil, tomatoes, garlic, parmesan cheese, ground black pepper, chicken broth, onion, orzo pasta
#
#   4. eastern mediterranean potato salad (ID: 36759)
#      Similarity: 0.25
#      Ingredients: fresh lemon juice, extra virgin olive oil, boiling potatoes, parsley, tomatoes, salt & freshly ground black pepper, onion, capers, cayenne pepper, olive
#
#   5. easy low fat  low carb low cal diet soup (ID: 304239)
#      Similarity: 0.25
#      Ingredients: vegetable bouillon cube, cabbage, water, fresh green herbs, tomatoes, salt, celery rib, bay leaf, onion, cucumber
#
# --------------------------------------------------
# Recipes similar to 'basil  cilantro and macadamia nut chicken':
#
#   1. easy tandoori marinade (ID: 220044)
#      Similarity: 0.31
#      Ingredients: ground cumin, garlic, turmeric, ground coriander, plain yogurt, chili powder, fresh ginger
#
#   2. tandoori marinade (ID: 472366)
#      Similarity: 0.29
#      Ingredients: garlic cloves, ground cumin, salt, garam masala, ground coriander, ground red pepper, plain yogurt, fresh ginger
#
#   3. new potatoes in spinach sauce (ID: 111844)
#      Similarity: 0.28
#      Ingredients: cilantro leaf, baby spinach, cherry tomatoes, garlic cloves, ground cumin, water, salt, tomatoes, paprika, garam masala, cilantro, ground coriander, onion, small red potatoes, vegetable oil, plain yogurt, fresh ginger, jalapenos
#
#   4. simple red lentil dhal (ID: 254106)
#      Similarity: 0.28
#      Ingredients: red onion, olive oil, lime juice, garlic cloves, green chili pepper, ground cumin, red lentils, cilantro, fresh ginger
#
#   5. tandoori prawn  shrimp  skewers (ID: 237324)
#      Similarity: 0.28
#      Ingredients: ground cumin, garlic, prawns, turmeric, ground coriander, plain yogurt, chili powder, fresh ginger, skewers
#
# --------------------------------------------------
# Recipes similar to 'fillet of sole with white wine   walnuts':
#
#   1. carrots sauteed in wine (ID: 398115)
#      Similarity: 0.38
#      Ingredients: butter, chicken broth, white wine, baby carrots
#
#   2. garlic butter sauce (ID: 197560)
#      Similarity: 0.38
#      Ingredients: butter, chicken broth, parsley, garlic
#
#   3. creamed chicken with mushrooms   atkins    4 5 net carbs (ID: 498010)
#      Similarity: 0.31
#      Ingredients: chicken cutlets, shallot, white wine, parsley, heavy cream, chicken broth, salt and pepper, thyme, mushrooms, butter
#
#   4. gram s garlic chicken strips (ID: 344762)
#      Similarity: 0.31
#      Ingredients: white wine, olive oil, parsley, salt, pepper, chicken broth, chicken tenders, butter, minced garlic cloves, cooked white rice
#
#   5. dude s ginger carrots (ID: 210695)
#      Similarity: 0.30
#      Ingredients: baby carrots, brown sugar, parsley, chicken broth, butter, fresh ginger
#
# --------------------------------------------------
# Recipes similar to 'grilled cheese chipotle sandwich':
#
#   1. grilled cheese perfection (ID: 32702)
#      Similarity: 0.38
#      Ingredients: cheese, butter, bread, tomatoes
#
#   2. fried tomatoes with basil (ID: 239940)
#      Similarity: 0.33
#      Ingredients: olive oil, fresh basil, tomatoes, cheese, butter
#
#   3. grilled cheese on the grill (ID: 127960)
#      Similarity: 0.33
#      Ingredients: bacon, tomatoes, white bread, cheddar cheese, butter
#
#   4. grilled cheese  pickle and tomato sandwiches (ID: 218820)
#      Similarity: 0.33
#      Ingredients: tomatoes, white bread, kosher dill pickle, butter, american cheese
#
#   5. kittencal s grilled cheese and tomato sandwich (ID: 322149)
#      Similarity: 0.33
#      Ingredients: mayonnaise, tomatoes, white bread, butter, american cheese
#
# --------------------------------------------------
